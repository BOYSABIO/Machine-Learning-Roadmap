# %%
import requests 
import json 
import pandas as pd

request = requests.get('https://fakerapi.it/api/v2/addresses?_quantity=10')
df = pd.DataFrame(request.json()['data'])

df
# Out:
#    id                         street          streetName buildingNumber  \
# 0   1           52307 Keebler Branch      Leopold Branch          35651
# 1   2                 474 Lang Forge   Hildegard Parkway           3834
# 2   3                 5411 Welch Via      Cory Stravenue           8698
# 3   4              11139 Pagac Point     Rosenbaum Plaza          77612
# 4   5  579 Goyette Streets Suite 119         Kari Bridge           2233
# 5   6   89399 Schulist Port Apt. 709         Treva Knoll          14435
# 6   7  70917 Lisandro Dale Suite 977        Lance Forest          47866
# 7   8    9901 Casper Lakes Suite 822  Bashirian Junction           9189
# 8   9              633 Mariela Shoal          Tromp Cove          70387
# 9  10     19874 Nigel Crest Apt. 190       Kirlin Lights            508
#
#                 city     zipcode      country country_code   latitude  \
# 0        Osinskiside       53236   Costa Rica           CR  62.624763
# ...
