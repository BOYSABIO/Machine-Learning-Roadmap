# %% [markdown]
# # 🎵 Apple Music Stream Data Analysis

# %% [markdown]
# In this project, we are going to explore my personal music streaming data from Apple Music. Apple Music is a music and video streaming service developed by Apple Inc. The dataset used here showcases my personal streaming on the platform.

# %% [markdown]
# We can see many things in the dataset like
#
# - List of songs played
# - List of Singers/Artists
# - Start time and position of songs
# - Music Labels
#
# and much more.
#
# I got this data from Apple's privacy website.

# %% [markdown]
# ## Requesting and downloading data
#
# Follow these steps request your personal data from apple
# - Go to privacy.apple.com
# - Log in to your account
# - Click on **Request a copy of your data**
# - Be sure to check mark on **Apple Media Services Information** and click on continue at bottom
# - Choose default size and click on **Complete Request**
#
# Check the below screenshots for reference

# %% [markdown]
# ![Picture title](image-20210605-194813.png)

# %% [markdown]
# ![Picture title](image-20210605-194845.png)

# %% [markdown]
# ![Picture title](image-20210605-194900.png)

# %% [markdown]
# ## Data Preparation and cleaning
#
#
# Steps:-
#
# 1. Load the dataset (csv file)
# 2. Check for shape and columns of dataframe
# 3. Check for missing values
# 4. Check the basic statistics of columns

# %%
file_path = 'Apple Music Play Activity.csv'

# %%
# Install plotly express if not already installed
# !pip install plotly_express --quiet

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly_express as px

pd.set_option('display.max_columns', None)

# %%
from matplotlib import rcParams
# figure size in inches
rcParams['figure.figsize'] = 12, 8

# %%
music_df = pd.read_csv(file_path)
# Out:
# C:\Users\SLO\AppData\Local\Temp\ipykernel_21676\3177787723.py:1: DtypeWarning: Columns (3,6,14,35,49,50,95,97,118) have mixed types. Specify dtype option on import or set low_memory=False.
#   music_df = pd.read_csv(file_path)

# %%
music_df.head()
# Out:
#   Age Bucket                        Album Name  Apple ID Number  \
# 0        NaN                         Everybody       1182611847
# 1        NaN                         Everybody       1182611847
# 2        NaN              SremmLife 2 (Deluxe)       1182611847
# 3        NaN                 Borracho - Single       1182611847
# 4      25-34  Life After Death (2014 Remaster)       1182611847
#
#   Apple Music Subscription Auto Play  \
# 0                     True       NaN
# 1                     True       NaN
# 2                     True       NaN
# 3                     True       NaN
# 4                     True  AUTO_OFF
#
#                                        Build Version Bundle Version  \
# 0  Music/3.1 iOS/10.3.1 model/iPhone8,1 hwp/s8003...            NaN
# 1  iTunes/12.7.0.166 (Macintosh; OS X 10.12.6) Ap...            NaN
# 2  Music/3.1 iOS/12.1.4 model/iPhone9,3 hwp/t8010...            NaN
# 3  Music/3.1 iOS/13.5.1 model/iPhone12,1 hwp/t803...            NaN
# 4  Music/3.1 iOS/18.1.1 model/iPhone14,7 hwp/t811...            3.1
#
#    Camera Option  Carrier Name Client Build Version  \
# 0            NaN           NaN                  NaN
# 1            NaN           NaN                  NaN
# 2            NaN           NaN                  NaN
# 3            NaN           NaN                  NaN
# 4            NaN           NaN                  NaN
#
#                                   Client Device Name  \
# 0  itunesstored/1.0 iOS/10.3.1 model/iPhone8,1 hw...
# 1  iTunes/12.7 (Macintosh; OS X 10.12.6) AppleWeb...
# 2  itunescloudd/1.0 iOS/12.1.4 model/iPhone9,3 hw...
# 3  itunescloudd/1.0 iOS/13.5.1 model/iPhone12,1 h...
# 4  itunescloudd/1.0 iOS/18.1.1 model/iPhone14,7 h...
#
#                         Client IP Address Client Platform  \
# 0                           91.54.241.193            FUSE
# 1                            91.54.254.90            FUSE
# 2  2a01:598:9280:4f81:28bd:8f9e:86b1:6500            FUSE
# 3                            217.80.254.6            FUSE
# 4                                     NaN            FUSE
#
#    Container Album Name Container Artist Name Container Global Playlist ID  \
# 0             Everybody                   NaN                          NaN
# 1             Everybody                   NaN                          NaN
# 2  SremmLife 2 (Deluxe)                   NaN                          NaN
# 3                   NaN                   NaN          pl.u-b3b8aL3cddoykb
# 4                   NaN                   NaN          pl.u-LdbqWd5FRRJxNl
#
#           Container ID  Container iTunes Playlist ID Container Library ID  \
# 0           1221017205                           NaN                  NaN
# 1           1221017205                           NaN                  NaN
# 2           1104588126                           NaN                  NaN
# 3  pl.u-b3b8aL3cddoykb                   256008457.0                  NaN
# 4  pl.u-LdbqWd5FRRJxNl                   256008977.0                  NaN
#
#   Container Name Container Origin Type  Container Personalized ID  \
# 0      l.VPTPZRc                   NaN                        NaN
# 1      l.VPTPZRc                   NaN                        NaN
# 2      l.jqyKK1z                   NaN                        NaN
# 3            NaN                   NaN                        NaN
# 4            NaN         USER_PLAYLIST                        NaN
#
#                                Container Playlist ID  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  f0df0dd31c7e25d675bdae99b3a7915d8b0823c7c88b84...
#
#   Container Radio Station ID Container Radio Station Version  \
# 0                        NaN                             NaN
# 1                        NaN                             NaN
# 2                        NaN                             NaN
# 3                        NaN                             NaN
# 4                        NaN                             NaN
#
#    Container Season ID Container Type  Contingency Device App Name  \
# 0                  NaN          ALBUM          NaN             NaN
# 1                  NaN          ALBUM          NaN             NaN
# 2                  NaN          ALBUM          NaN             NaN
# 3                  NaN       PLAYLIST          NaN             NaN
# 4                  NaN       PLAYLIST          NaN           Music
#
#   Device App Version                         Device Identifier Device OS Name  \
# 0                NaN  24c5f75e58e29a108c477a2f748e9c27549af4e3            NaN
# 1                NaN                              8438354F51A2            NaN
# 2                NaN  c3633be6a1e9244479e0cbfddd723f5d108b972d            NaN
# 3                NaN                 00008030-001C30300C10802E            NaN
# 4                3.1                                       NaN            iOS
#
#   Device OS Version Device Type  Display Count Display Language  \
# 0               NaN         NaN            NaN              NaN
# 1               NaN         NaN            NaN              NaN
# 2               NaN         NaN            NaN              NaN
# 3               NaN         NaN            NaN              NaN
# 4            18.1.1      IPHONE            NaN              NaN
#
#                 Display Type  End Position In Milliseconds  \
# 0  NO_DISPLAY_TYPE_SPECIFIED                      250241.0
# 1  NO_DISPLAY_TYPE_SPECIFIED                        6406.0
# 2  NO_DISPLAY_TYPE_SPECIFIED                           0.0
# 3  NO_DISPLAY_TYPE_SPECIFIED                        2586.0
# 4  NO_DISPLAY_TYPE_SPECIFIED                         202.0
#
#                              End Reason Type  \
# 0                       NATURAL_END_OF_TRACK
# 1  MANUALLY_SELECTED_PLAYBACK_OF_A_DIFF_ITEM
# 2  MANUALLY_SELECTED_PLAYBACK_OF_A_DIFF_ITEM
# 3  MANUALLY_SELECTED_PLAYBACK_OF_A_DIFF_ITEM
# 4                     TRACK_SKIPPED_FORWARDS
#
#                                   Evaluation Variant  \
# 0  [{"areaId":"isj11bm","bucket":1550,"treatmentI...
# 1  [{"areaId":"isj11bm","bucket":9933,"treatmentI...
# 2  [{"areaId":"NyCxKBD","bucket":4117,"treatmentI...
# 3  [{"areaId":"tBc9hUt","bucket":-2,"treatmentId"...
# 4  [{"areaId":"ZPJNBED","bucket":-2,"treatmentId"...
#
#         Event End Timestamp              Event ID  Event Post Date Time  \
# 0  2017-05-07T13:57:49.384Z  -7473504841534309543                   NaN
# 1  2017-09-24T08:53:45.578Z   5029267887006928478                   NaN
# 2  2019-04-09T05:59:44.553Z  -2646731834954432110                   NaN
# 3  2020-06-24T22:26:58.405Z   3407567189458564142                   NaN
# 4  2024-12-04T13:17:01.866Z   8957038919126515919            28888690.0
#
#   Event Reason Hint Type  Event Received Timestamp     Event Start Timestamp  \
# 0          NOT_SPECIFIED  2017-05-07T13:57:49.609Z  2017-05-07T13:53:39.143Z
# 1          NOT_SPECIFIED  2017-09-24T08:53:45.578Z  2017-09-24T08:53:39.172Z
# 2          NOT_SPECIFIED  2019-04-09T05:59:45.696Z  2019-04-09T05:59:44.553Z
# 3          NOT_SPECIFIED  2020-06-24T22:26:58.548Z  2020-06-24T22:26:55.819Z
# 4          NOT_SPECIFIED  2024-12-04T13:17:02.013Z  2024-12-04T13:17:01.664Z
#
#             Event Timestamp Event Type                           Feature Name  \
# 0                       NaN   PLAY_END                 library / album_detail
# 1                       NaN   PLAY_END                                library
# 2                       NaN   PLAY_END                 library / album_detail
# 3                       NaN   PLAY_END              library / playlist_detail
# 4  2024-12-04T13:17:01.866Z   PLAY_END  library / playlists / playlist_detail
#
#   Grouping House ID IP City IP Country Code  IP Latitude  IP Longitude  \
# 0      NaN      NaN     NaN             NaN          NaN           NaN
# 1      NaN      NaN     NaN             NaN          NaN           NaN
# 2      NaN      NaN     NaN             NaN          NaN           NaN
# 3      NaN      NaN     NaN             NaN          NaN           NaN
# 4      NaN      NaN  MUNICH              DE        48.15         11.58
#
#   IP Network IP Network Type IP Region Code Is CMA Station Is Collaborative  \
# 0        NaN             NaN            NaN            NaN              NaN
# 1        NaN             NaN            NaN            NaN              NaN
# 2        NaN             NaN            NaN            NaN              NaN
# 3        NaN             NaN            NaN            NaN              NaN
# 4       dtag          mobile             BY            NaN              NaN
#
#   Is Delegated Is Heatseeker Station Is Heavy Rotation Station  \
# 0          NaN                   NaN                       NaN
# 1        False                   NaN                       NaN
# 2        False                   NaN                       NaN
# 3        False                   NaN                       NaN
# 4        False                   NaN                       NaN
#
#   Is Subscription Owner? Is Vocal Attenuation ISO Country  \
# 0                    NaN                  NaN         NaN
# 1                    NaN                  NaN         NaN
# 2                    NaN                  NaN         NaN
# 3                    NaN                  NaN         NaN
# 4                  False     ATTENUATION_TRUE          US
#
#               Item Type  Key Request  Lease Limit  Legacy Playback ID  \
# 0  ITUNES_STORE_CONTENT          NaN          NaN                 NaN
# 1  ITUNES_STORE_CONTENT          NaN          NaN                 NaN
# 2  ITUNES_STORE_CONTENT          NaN          NaN                 NaN
# 3  ITUNES_STORE_CONTENT          NaN          NaN                 NaN
# 4  ITUNES_STORE_CONTENT          NaN          NaN                 NaN
#
#    Local Radio Station ID  Local Radio Station TuneIn ID Managed ID  \
# 0                     NaN                            NaN        NaN
# 1                     NaN                            NaN        NaN
# 2                     NaN                            NaN        NaN
# 3                     NaN                            NaN        NaN
# 4                     NaN                            NaN      False
#
#    Matched Content Media Bundle App Name     Media Bundle Type  \
# 0              NaN                   NaN  BUNDLE_NOT_SPECIFIED
# 1              NaN                   NaN  BUNDLE_NOT_SPECIFIED
# 2              NaN                   NaN  BUNDLE_NOT_SPECIFIED
# 3              NaN                   NaN  BUNDLE_NOT_SPECIFIED
# 4              NaN       com.apple.Music                NATIVE
#
#    Media Duration In Milliseconds Media Type               Metrics Client ID  \
# 0                        250241.0      AUDIO  3z4HqStGz7TBz4eiz9UHz1Bt1ZMYME
# 1                        206300.0      AUDIO   3z3hlyxOzF6yz5IPzCExzs8JdfyZs
# 2                        208111.0      AUDIO  3z17xDCUz2tWz4sazA9Tz1EiZkpm3g
# 3                        197416.0      AUDIO  3z2wAvN7zA9Mz4q1zAXjz1KHC3KZYj
# 4                        307426.0      AUDIO                             NaN
#
#    Milliseconds Since Play Offline  Ownership Type  Personalized Name  \
# 0                    225.0   False             1.0                NaN
# 1                      0.0   False             1.0                NaN
# 2                   1143.0   False             1.0                NaN
# 3                    143.0   False             1.0        256008457.0
# 4                    147.0   False             1.0        256008977.0
#
#    Play Duration Milliseconds  Promotion Scenario ID  \
# 0                    250241.0                    NaN
# 1                      6406.0                    NaN
# 2                         0.0                    NaN
# 3                      2586.0                    NaN
# 4                       202.0           9.900000e+11
#
#    Provided Audio Bit Depth Provided Audio Channel  \
# 0                       NaN                    NaN
# 1                       NaN                    NaN
# 2                       NaN                    NaN
# 3                       NaN                    NaN
# 4                       NaN                    NaN
#
#    Provided Audio Sample Rate  Provided Bit Rate Provided Codec  \
# 0                         NaN                NaN            NaN
# 1                         NaN                NaN            NaN
# 2                         NaN                NaN            NaN
# 3                         NaN                NaN            NaN
# 4                         NaN                NaN            NaN
#
#   Provided Playback Format  Provider ID  Radio Format Radio Seed ID  \
# 0                      NaN          NaN           NaN           NaN
# 1                      NaN          NaN           NaN           NaN
# 2                      NaN          NaN           NaN           NaN
# 3                      NaN          NaN           NaN           NaN
# 4                      NaN          2.0           NaN           NaN
#
#    Radio Station Country Radio Station ID  Radio Station Position Radio Type  \
# 0                    NaN              NaN                     NaN        NaN
# 1                    NaN              NaN                     NaN        NaN
# 2                    NaN              NaN                     NaN        NaN
# 3                    NaN              NaN                     NaN        NaN
# 4                    NaN              NaN                     NaN        NaN
#
#    Radio User ID Referral ID Repeat Play  Report Type Royalty Free  \
# 0            NaN         NaN         NaN          NaN          NaN
# 1            NaN         NaN         NaN          NaN          NaN
# 2            NaN         NaN         NaN          NaN          NaN
# 3            NaN         NaN         NaN          NaN          NaN
# 4            NaN         NaN  REPEAT_OFF          NaN        False
#
#    Sales Order Vendor ID Session Is Shared Shared Activity Devices-Current  \
# 0                    NaN               NaN                             NaN
# 1                    NaN               NaN                             NaN
# 2                    NaN               NaN                             NaN
# 3                    NaN               NaN                             NaN
# 4             80026919.0             False                             NaN
#
#   Shared Activity Devices-Max Shared Activity Type Shelf Content Identifier  \
# 0                         NaN                  NaN                      NaN
# 1                         NaN                  NaN                      NaN
# 2                         NaN                  NaN                      NaN
# 3                         NaN                  NaN                      NaN
# 4                         NaN                  NaN                      NaN
#
#    Shelf Content Position  Shelf Index Shelf Type Shelf Visible Shuffle Play  \
# 0                     NaN          NaN        NaN           NaN          NaN
# 1                     NaN          NaN        NaN           NaN          NaN
# 2                     NaN          NaN        NaN           NaN          NaN
# 3                     NaN          NaN        NaN           NaN          NaN
# 4                     NaN          NaN        NaN           NaN   SHUFFLE_ON
#
#   Siri Request                                     Song Name  Source Model  \
# 0          NaN  1-800-273-8255 (feat. Alessia Cara & Khalid)           NaN
# 1          NaN                                Mos Definitely           NaN
# 2        False                                         Swang           NaN
# 3        False                                      Borracho           NaN
# 4        False                            Going Back to Cali           NaN
#
#    Source Radio Name Source Radio Type         Source Type  \
# 0                NaN               NaN  ORIGINATING_DEVICE
# 1                NaN               NaN  ORIGINATING_DEVICE
# 2                NaN               NaN  ORIGINATING_DEVICE
# 3                NaN               NaN  ORIGINATING_DEVICE
# 4                NaN               NaN  ORIGINATING_DEVICE
#
#    Start Position In Milliseconds Store Front Name  Subscribed State  \
# 0                               0    United States               NaN
# 1                               0    United States               NaN
# 2                               0    United States               NaN
# 3                               0    United States               NaN
# 4                               0    United States               NaN
#
#    Subscription Bundle ID  Subscription Discovery Mode  Subscription Offer ID  \
# 0                     NaN                          NaN                    NaN
# 1                     NaN                          NaN                    NaN
# 2                     NaN                          NaN                    NaN
# 3                     NaN                          NaN                    NaN
# 4            6.450019e+09                          NaN                    NaN
#
#   Subscription Pool Type  Subscription User ID Use Listening History  \
# 0                    NaN                   NaN                   NaN
# 1                    NaN                   NaN                 False
# 2                    NaN                   NaN                 False
# 3                    NaN                   NaN                 False
# 4                    XCX          1.608221e+09                 False
#
#   User’s Audio Quality User’s Playback Format  UTC Offset In Seconds  \
# 0                  NaN                    NaN                 7200.0
# 1                  NaN                    NaN                 7200.0
# 2                  NaN                    NaN                 7200.0
# 3                  NaN                    NaN                 7200.0
# 4         HIGH_QUALITY                SPATIAL                 3600.0
#
#    Vocal Attenuation Duration  Vocal Attenuation Model ID
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         0.0                         NaN

# %%
print("Rows x Columns: {}".format(music_df.shape))
# Out:
# Rows x Columns: (337971, 134)

# %%
# check for available columns
music_df.columns.to_list()
# Out:
# ['Age Bucket',
#  'Album Name',
#  'Apple ID Number',
#  'Apple Music Subscription',
#  'Auto Play',
#  'Build Version',
#  'Bundle Version',
#  'Camera Option',
#  'Carrier Name',
#  'Client Build Version',
#  'Client Device Name',
#  'Client IP Address',
#  'Client Platform',
#  'Container Album Name',
#  'Container Artist Name',
#  'Container Global Playlist ID',
#  'Container ID',
#  'Container iTunes Playlist ID',
#  'Container Library ID',
#  'Container Name',
#  'Container Origin Type',
#  'Container Personalized ID',
#  'Container Playlist ID',
#  'Container Radio Station ID',
#  'Container Radio Station Version',
#  'Container Season ID',
#  'Container Type',
#  'Contingency',
#  'Device App Name',
#  'Device App Version',
#  'Device Identifier',
#  'Device OS Name',
#  'Device OS Version',
#  'Device Type',
#  'Display Count',
#  'Display Language',
#  'Display Type',
#  'End Position In Milliseconds',
#  'End Reason Type',
#  'Evaluation Variant',
#  'Event End Timestamp',
#  'Event ID',
#  'Event Post Date Time',
#  'Event Reason Hint Type',
#  'Event Received Timestamp',
#  'Event Start Timestamp',
#  'Event Timestamp',
#  'Event Type',
#  'Feature Name',
#  'Grouping',
#  'House ID',
#  'IP City',
#  'IP Country Code',
#  'IP Latitude',
#  'IP Longitude',
#  'IP Network',
#  'IP Network Type',
#  'IP Region Code',
#  'Is CMA Station',
#  'Is Collaborative',
#  'Is Delegated',
#  'Is Heatseeker Station',
#  'Is Heavy Rotation Station',
#  'Is Subscription Owner?',
#  'Is Vocal Attenuation',
#  'ISO Country',
#  'Item Type',
#  'Key Request',
#  'Lease Limit',
#  'Legacy Playback ID',
#  'Local Radio Station ID',
#  'Local Radio Station TuneIn ID',
#  'Managed ID',
#  'Matched Content',
#  'Media Bundle App Name',
#  'Media Bundle Type',
#  'Media Duration In Milliseconds',
#  'Media Type',
#  'Metrics Client ID',
#  'Milliseconds Since Play',
#  'Offline',
#  'Ownership Type',
#  'Personalized Name',
#  'Play Duration Milliseconds',
#  'Promotion Scenario ID',
#  'Provided Audio Bit Depth',
#  'Provided Audio Channel',
#  'Provided Audio Sample Rate',
#  'Provided Bit Rate',
#  'Provided Codec',
#  'Provided Playback Format',
#  'Provider ID',
#  'Radio Format',
#  'Radio Seed ID',
#  'Radio Station Country',
#  'Radio Station ID',
#  'Radio Station Position',
#  'Radio Type',
#  'Radio User ID',
#  'Referral ID',
#  'Repeat Play',
#  'Report Type',
#  'Royalty Free',
#  'Sales Order Vendor ID',
#  'Session Is Shared',
#  'Shared Activity Devices-Current',
#  'Shared Activity Devices-Max',
#  'Shared Activity Type',
#  'Shelf Content Identifier',
#  'Shelf Content Position',
#  'Shelf Index',
#  'Shelf Type',
#  'Shelf Visible',
#  'Shuffle Play',
#  'Siri Request',
#  'Song Name',
#  'Source Model',
#  'Source Radio Name',
#  'Source Radio Type',
#  'Source Type',
#  'Start Position In Milliseconds',
#  'Store Front Name',
#  'Subscribed State',
#  'Subscription Bundle ID',
#  'Subscription Discovery Mode',
#  'Subscription Offer ID',
#  'Subscription Pool Type',
#  'Subscription User ID',
#  'Use Listening History',
#  'User’s Audio Quality',
#  'User’s Playback Format',
#  'UTC Offset In Seconds',
#  'Vocal Attenuation Duration',
#  'Vocal Attenuation Model ID']

# %% [markdown]
# display basic statistics of numerical variables

# %%
music_df.describe()
# Out:
#        Apple ID Number  Camera Option  Carrier Name  \
# count     3.379710e+05            0.0           0.0
# mean      1.182612e+09            NaN           NaN
# std       0.000000e+00            NaN           NaN
# min       1.182612e+09            NaN           NaN
# 25%       1.182612e+09            NaN           NaN
# 50%       1.182612e+09            NaN           NaN
# 75%       1.182612e+09            NaN           NaN
# max       1.182612e+09            NaN           NaN
#
#        Container iTunes Playlist ID  Container Personalized ID  \
# count                  1.317020e+05               1.900000e+01
# mean                   2.557835e+08               7.974080e+08
# std                    7.561652e+06               9.439705e+07
# min                    2.000000e+00               7.576230e+08
# 25%                    2.560069e+08               7.576230e+08
# 50%                    2.560074e+08               7.576230e+08
# 75%                    2.560087e+08               7.576230e+08
# max                    2.560100e+08               1.009599e+09
#
#        Container Season ID  Contingency  Display Count  \
# count                  0.0          0.0          165.0
# mean                   NaN          NaN            0.0
# std                    NaN          NaN            0.0
# min                    NaN          NaN            0.0
# 25%                    NaN          NaN            0.0
# 50%                    NaN          NaN            0.0
# 75%                    NaN          NaN            0.0
# max                    NaN          NaN            0.0
#
#        End Position In Milliseconds  Event Post Date Time    IP Latitude  \
# count                  3.336250e+05          2.591800e+04  103132.000000
# mean                   7.043316e+04          2.882500e+07      47.340600
# std                    5.118003e+05          3.770959e+04       5.101272
# min                   -1.130000e+02          2.872036e+07       9.870000
# 25%                    2.140000e+02          2.879336e+07      40.410000
# 50%                    6.808000e+03          2.882419e+07      50.120000
# 75%                    1.047180e+05          2.885672e+07      50.120000
# max                    1.309173e+08          2.889214e+07      53.550000
#
#         IP Longitude  Key Request  Lease Limit  Legacy Playback ID  \
# count  103132.000000          0.0          0.0              2355.0
# mean        2.520307          NaN          NaN                 0.0
# std        17.362226          NaN          NaN                 0.0
# min      -122.693700          NaN          NaN                 0.0
# 25%        -3.710000          NaN          NaN                 0.0
# 50%         8.680000          NaN          NaN                 0.0
# 75%         8.680000          NaN          NaN                 0.0
# max        13.400000          NaN          NaN                 0.0
#
#        Local Radio Station ID  Local Radio Station TuneIn ID  Matched Content  \
# count                     9.0                            0.0              0.0
# mean              699250851.0                            NaN              NaN
# std                       0.0                            NaN              NaN
# min               699250851.0                            NaN              NaN
# 25%               699250851.0                            NaN              NaN
# 50%               699250851.0                            NaN              NaN
# 75%               699250851.0                            NaN              NaN
# max               699250851.0                            NaN              NaN
#
#        Media Duration In Milliseconds  Milliseconds Since Play  \
# count                    3.370080e+05             3.377590e+05
# mean                     2.039296e+05             3.723864e+07
# std                      1.282999e+05             6.025856e+08
# min                      0.000000e+00            -5.819733e+08
# 25%                      1.575000e+05             1.010000e+02
# 50%                      1.968270e+05             3.840000e+02
# 75%                      2.373948e+05             3.495200e+04
# max                      9.647000e+06             2.087026e+10
#
#        Ownership Type  Personalized Name  Play Duration Milliseconds  \
# count   287496.000000       1.729270e+05                3.336250e+05
# mean         1.013931       2.558951e+08                6.009041e+04
# std          0.279127       8.758199e+06                5.107658e+05
# min          1.000000       2.000000e+00               -5.855930e+05
# 25%          1.000000       2.560026e+08                0.000000e+00
# 50%          1.000000       2.560072e+08                2.284000e+03
# 75%          1.000000       2.560082e+08                7.083500e+04
# max          7.000000       1.009599e+09                1.309173e+08
#
#        Promotion Scenario ID  Provided Audio Bit Depth  \
# count           4.174600e+04                    3933.0
# mean            9.900000e+11                       0.0
# std             1.220718e-04                       0.0
# min             9.900000e+11                       0.0
# 25%             9.900000e+11                       0.0
# 50%             9.900000e+11                       0.0
# 75%             9.900000e+11                       0.0
# max             9.900000e+11                       0.0
#
#        Provided Audio Sample Rate  Provided Bit Rate   Provider ID  \
# count                      3933.0        3933.000000  5.273200e+04
# mean                          0.0      695619.628782  1.031923e+07
# std                           0.0      185143.253055  3.225250e+07
# min                           0.0       64000.000000  2.000000e+00
# 25%                           0.0      768000.000000  1.846000e+03
# 50%                           0.0      768000.000000  7.567000e+03
# 75%                           0.0      768000.000000  1.351426e+06
# max                           0.0      768000.000000  1.241603e+08
#
#        Radio Format  Radio Station Country  Radio Station Position  \
# count           0.0                    0.0               21.000000
# mean            NaN                    NaN                3.142857
# std             NaN                    NaN                3.863751
# min             NaN                    NaN                0.000000
# 25%             NaN                    NaN                0.000000
# 50%             NaN                    NaN                1.000000
# 75%             NaN                    NaN                6.000000
# max             NaN                    NaN               11.000000
#
#        Radio User ID  Report Type  Sales Order Vendor ID  \
# count            0.0    81.000000           5.263000e+04
# mean             NaN     1.444444           8.349296e+07
# std              NaN     0.500000           3.640752e+06
# min              NaN     1.000000           8.002692e+07
# 25%              NaN     1.000000           8.002692e+07
# 50%              NaN     1.000000           8.500408e+07
# 75%              NaN     2.000000           8.581037e+07
# max              NaN     2.000000           9.303535e+07
#
#        Shelf Content Position  Shelf Index  Source Model  Source Radio Name  \
# count                     0.0  8060.000000           0.0                0.0
# mean                      NaN     4.191315           NaN                NaN
# std                       NaN     3.433031           NaN                NaN
# min                       NaN     0.000000           NaN                NaN
# 25%                       NaN     1.000000           NaN                NaN
# 50%                       NaN     5.000000           NaN                NaN
# 75%                       NaN     5.000000           NaN                NaN
# max                       NaN    16.000000           NaN                NaN
#
#        Start Position In Milliseconds  Subscribed State  \
# count                    3.379710e+05               0.0
# mean                     1.034276e+04               NaN
# std                      4.464773e+04               NaN
# min                      0.000000e+00               NaN
# 25%                      0.000000e+00               NaN
# 50%                      0.000000e+00               NaN
# 75%                      0.000000e+00               NaN
# max                      5.648821e+06               NaN
#
#        Subscription Bundle ID  Subscription Discovery Mode  \
# count            4.174600e+04                          0.0
# mean             5.514928e+09                          NaN
# std              1.905095e+09                          NaN
# min              1.633698e+09                          NaN
# 25%              6.450019e+09                          NaN
# 50%              6.450019e+09                          NaN
# 75%              6.450019e+09                          NaN
# max              6.450019e+09                          NaN
#
#        Subscription Offer ID  Subscription User ID  UTC Offset In Seconds  \
# count                    0.0          4.174600e+04          336877.000000
# mean                     NaN          1.608221e+09            4370.585110
# std                      NaN          0.000000e+00            5591.086928
# min                      NaN          1.608221e+09          -28800.000000
# 25%                      NaN          1.608221e+09            3600.000000
# 50%                      NaN          1.608221e+09            7200.000000
# 75%                      NaN          1.608221e+09            7200.000000
# max                      NaN          1.608221e+09           10800.000000
#
#        Vocal Attenuation Duration  Vocal Attenuation Model ID
# count                54814.000000                         0.0
# mean                     1.397161                         NaN
# std                    173.680100                         NaN
# min                      0.000000                         NaN
# 25%                      0.000000                         NaN
# 50%                      0.000000                         NaN
# 75%                      0.000000                         NaN
# max                  31169.000000                         NaN

# %%
music_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 337971 entries, 0 to 337970
# Columns: 134 entries, Age Bucket to Vocal Attenuation Model ID
# dtypes: float64(45), int64(2), object(87)
# memory usage: 345.5+ MB

# %% [markdown]
# Check for the no. of missing values in each column

# %%
music_df.isnull().sum()
# Out:
# Age Bucket                    306313
# Album Name                     53079
# Apple ID Number                    0
# Apple Music Subscription          26
# Auto Play                     202284
#                                ...
# User’s Audio Quality          330324
# User’s Playback Format        330324
# UTC Offset In Seconds           1094
# Vocal Attenuation Duration    283157
# Vocal Attenuation Model ID    337971
# Length: 134, dtype: int64

# %%
sns.heatmap(music_df.isnull())
plt.show()

# %% [markdown]
# Our DataFrame many columns which have all the NULL values. Such columns have to be removed from the dataset.  Our goal should be making the above HeatMap as dark as possible (i.e without any white marks)

# %%
nans = [col for col in music_df.columns if music_df[col].isnull().all() == True]

# %%
# drop the above columns from the dataframe
music_df.drop(nans, axis=1, inplace=True)

# %%
# check for current shape of df
music_df.shape
# Out:
# (337971, 116)

# %% [markdown]
# We have reduced our DataFrame columns from 45 cols -&gt; 30 cols

# %%
music_df.isnull().sum()
# Out:
# Age Bucket                    306313
# Album Name                     53079
# Apple ID Number                    0
# Apple Music Subscription          26
# Auto Play                     202284
#                                ...
# Use Listening History          99378
# User’s Audio Quality          330324
# User’s Playback Format        330324
# UTC Offset In Seconds           1094
# Vocal Attenuation Duration    283157
# Length: 116, dtype: int64

# %% [markdown]
# There are more columns like ID's which are not going to contribute much in our analysis. So we will drop these columns as well manually

# %%
columns_to_delete = ['Container Playlist ID', 'Container Radio Station Version', 'Device App Version', 'Device Identifier', 'Device OS Name', 'Device OS Version', 'Device Type', 'Display Count', 'Display Language', 'Display Type', 'Evaluation Variant', 'Event ID', 'Grouping', 'House ID', 'IP City', 'IP Country Code', 'IP Latitude', 'IP Longitude', 'IP Network', 'IP Network Type', 'IP Region Code', 'Is CMA Station', 'Is Collaborative', 'Is Delegated', 'Is Heatseeker Station', 'Is Subscription Owner?', 'Is Vocal Attenuation', 'ISO Country', 'Legacy Playback ID', 'Local Radio Station ID', 'Managed ID', 'Media Bundle App Name', 'Media Bundle Type', 'Promotion Scenario ID', 'Provided Audio Bit Depth', 'Provided Audio Sample Rate', 'Provided Bit Rate', 'Provided Codec', 'Provided Playback Format',	'Provider ID',	'Radio Seed ID', 'Radio Station ID', 'Radio Station Position',	'Radio Type', 'Referral ID', 'Repeat Play',	'Report Type', 'Royalty Free',	'Sales Order Vendor ID', 'Session Is Shared',	'Shared Activity Devices-Current',	'Shared Activity Devices-Max',	'Shared Activity Type',	'Shelf Content Identifier',	'Shelf Index',	'Shelf Type',	'Shelf Visible']
music_df.drop(columns_to_delete, axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 2
#       1 columns_to_delete = ['Container Playlist ID', 'Container Radio Station Version', 'Device App Version', 'Device Identifier', 'Device OS Name', 'Device OS Version', 'Device Type', 'Display Count', 'Display Language', 'Display Type', 'Evaluation Variant', 'Event ID', 'Grouping', 'House ID', 'IP City', 'IP Country Code', 'IP Latitude', 'IP Longitude', 'IP Network', 'IP Network Type', 'IP Region Code', 'Is CMA Station', 'Is Collaborative', 'Is Delegated', 'Is Heatseeker Station', 'Is Subscription Owner?', 'Is Vocal Attenuation', 'ISO Country', 'Legacy Playback ID', 'Local Radio Station ID', 'Managed ID', 'Media Bundle App Name', 'Media Bundle Type', 'Promotion Scenario ID', 'Provided Audio Bit Depth', 'Provided Audio Sample Rate', 'Provided Bit Rate', 'Provided Codec', 'Provided Playback Format',	'Provider ID',	'Radio Seed ID', 'Radio Station ID', 'Radio Station Position',	'Radio Type', 'Referral ID', 'Repeat Play',	'Report Type', 'Royalty Free',	'Sales Order Vendor ID', 'Session Is Shared',	'Shared Activity Devices-Current',	'Shared Activity Devices-Max',	'Shared Activity Type',	'Shelf Content Identifier',	'Shelf Index',	'Shelf Type',	'Shelf Visible']
# ----> 2 music_df.drop(columns_to_delete, axis=1, inplace=True)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\generic.py:4549, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547 for axis, labels in axes.items():
#    4548     if labels is not None:
# -> 4549         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4551 if inplace:
#    4552     self._update_inplace(obj)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\generic.py:4591, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4589         new_axis = axis.drop(labels, level=level, errors=errors)
#    4590     else:
# -> 4591         new_axis = axis.drop(labels, errors=errors)
#    4592     indexer = axis.get_indexer(new_axis)
#    4594 # Case for non-unique axis
#    4595 else:
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\indexes\base.py:6699, in Index.drop(self, labels, errors)
#    6697 if mask.any():
#    6698     if errors != "ignore":
# -> 6699         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6700     indexer = indexer[~mask]
#    6701 return self.delete(indexer)
#
# KeyError: "['Container Playlist ID', 'Container Radio Station Version', 'Device App Version', 'Device Identifier', 'Device OS Name', 'Device OS Version', 'Device Type', 'Display Count', 'Display Language', 'Display Type', 'Evaluation Variant', 'Event ID', 'Grouping', 'House ID', 'IP City', 'IP Country Code', 'IP Latitude', 'IP Longitude', 'IP Network', 'IP Network Type', 'IP Region Code', 'Is CMA Station', 'Is Collaborative', 'Is Delegated', 'Is Heatseeker Station', 'Is Subscription Owner?', 'Is Vocal Attenuation', 'ISO Country', 'Legacy Playback ID', 'Local Radio Station ID', 'Managed ID', 'Media Bundle App Name', 'Media Bundle Type', 'Promotion Scenario ID', 'Provided Audio Bit Depth', 'Provided Audio Sample Rate', 'Provided Bit Rate', 'Provided Codec', 'Provided Playback Format', 'Provider ID', 'Radio Seed ID', 'Radio Station ID', 'Radio Station Position', 'Radio Type', 'Referral ID', 'Repeat Play', 'Report Type', 'Royalty Free', 'Sales Order Vendor ID', 'Session Is Shared', 'Shared Activity Devices-Current', 'Shared Activity Devices-Max', 'Shared Activity Type', 'Shelf Content Identifier', 'Shelf Index', 'Shelf Type', 'Shelf Visible'] not found in axis"

# %%
music_df
# Out:
#        Age Bucket                                         Album Name  \
# 0             NaN                                          Everybody
# 1             NaN                                          Everybody
# 2             NaN                               SremmLife 2 (Deluxe)
# 3             NaN                                  Borracho - Single
# 4           25-34                   Life After Death (2014 Remaster)
# ...           ...                                                ...
# 337966        NaN                                    Outlet - Single
# 337967      25-34                           Cant Get Enough - Single
# 337968        NaN  Endless Pain (feat. kXpkX, LXNGVX, b1ueshxrtca...
# 337969      25-34                          Pretty Girl Vamp - Single
# 337970        NaN          Drug Dealer (feat. Ariana DeBoo) - Single
#
#         Apple ID Number Apple Music Subscription Auto Play  \
# 0            1182611847                     True       NaN
# 1            1182611847                     True       NaN
# 2            1182611847                     True       NaN
# 3            1182611847                     True       NaN
# 4            1182611847                     True  AUTO_OFF
# ...                 ...                      ...       ...
# 337966       1182611847                     True       NaN
# 337967       1182611847                     True  AUTO_OFF
# 337968       1182611847                     True  AUTO_OFF
# 337969       1182611847                     True  AUTO_OFF
# 337970       1182611847                     True       NaN
#
#                                             Build Version Bundle Version  \
# 0       Music/3.1 iOS/10.3.1 model/iPhone8,1 hwp/s8003...            NaN
# 1       iTunes/12.7.0.166 (Macintosh; OS X 10.12.6) Ap...            NaN
# 2       Music/3.1 iOS/12.1.4 model/iPhone9,3 hwp/t8010...            NaN
# 3       Music/3.1 iOS/13.5.1 model/iPhone12,1 hwp/t803...            NaN
# 4       Music/3.1 iOS/18.1.1 model/iPhone14,7 hwp/t811...            3.1
# ...                                                   ...            ...
# 337966  Music/3.0 iOS/10.2.1 model/iPhone8,1 hwp/s8003...            NaN
# 337967  Music/3.1 iOS/17.5.1 model/iPhone14,7 hwp/t811...            3.1
# 337968  Music/3.1 iOS/17.5.1 model/iPhone14,7 hwp/t811...            3.1
# 337969  Music/3.1 iOS/17.5.1 model/iPhone14,7 hwp/t811...            3.1
# 337970  Music/3.0 iOS/10.2.1 model/iPhone8,1 hwp/s8003...            NaN
#
#        Client Build Version  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ...                     ...
# 337966                  NaN
# 337967                  NaN
# 337968                  NaN
# 337969                  NaN
# 337970                  NaN
#
#                                        Client Device Name  \
# 0       itunesstored/1.0 iOS/10.3.1 model/iPhone8,1 hw...
# 1       iTunes/12.7 (Macintosh; OS X 10.12.6) AppleWeb...
# 2       itunescloudd/1.0 iOS/12.1.4 model/iPhone9,3 hw...
# 3       itunescloudd/1.0 iOS/13.5.1 model/iPhone12,1 h...
# 4       itunescloudd/1.0 iOS/18.1.1 model/iPhone14,7 h...
# ...                                                   ...
# 337966  itunesstored/1.0 iOS/10.2.1 model/iPhone8,1 hw...
# 337967  itunescloudd/1.0 iOS/17.5.1 model/iPhone14,7 h...
# 337968  itunescloudd/1.0 iOS/17.5.1 model/iPhone14,7 h...
# 337969  itunescloudd/1.0 iOS/17.5.1 model/iPhone14,7 h...
# 337970  itunesstored/1.0 iOS/10.2.1 model/iPhone8,1 hw...
#
#                              Client IP Address Client Platform  \
# 0                                91.54.241.193            FUSE
# 1                                 91.54.254.90            FUSE
# 2       2a01:598:9280:4f81:28bd:8f9e:86b1:6500            FUSE
# 3                                 217.80.254.6            FUSE
# 4                                          NaN            FUSE
# ...                                        ...             ...
# 337966                           80.187.101.68            FUSE
# 337967                                     NaN            FUSE
# 337968                                     NaN            FUSE
# 337969                                     NaN            FUSE
# 337970                           80.187.101.43            FUSE
#
#         Container Album Name Container Artist Name  \
# 0                  Everybody                   NaN
# 1                  Everybody                   NaN
# 2       SremmLife 2 (Deluxe)                   NaN
# 3                        NaN                   NaN
# 4                        NaN                   NaN
# ...                      ...                   ...
# 337966                   NaN                   NaN
# 337967                   NaN                   NaN
# 337968                   NaN                   NaN
# 337969                   NaN                   NaN
# 337970                   NaN                   NaN
#
#                Container Global Playlist ID  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                       pl.u-b3b8aL3cddoykb
# 4                       pl.u-LdbqWd5FRRJxNl
# ...                                     ...
# 337966  pl.eccc924305ad42ccb53c68aafe33995c
# 337967                  pl.u-6mo4zqytEErBW5
# 337968                                  NaN
# 337969                  pl.u-leylWE8F00qjWe
# 337970  pl.eccc924305ad42ccb53c68aafe33995c
#
#                                Container ID  Container iTunes Playlist ID  \
# 0                                1221017205                           NaN
# 1                                1221017205                           NaN
# 2                                1104588126                           NaN
# 3                       pl.u-b3b8aL3cddoykb                   256008457.0
# 4                       pl.u-LdbqWd5FRRJxNl                   256008977.0
# ...                                     ...                           ...
# 337966  pl.eccc924305ad42ccb53c68aafe33995c                   256002565.0
# 337967                  pl.u-6mo4zqytEErBW5                   256007429.0
# 337968               CgwIByIICIfz9LMEGAIQAQ                           NaN
# 337969                  pl.u-leylWE8F00qjWe                   256009221.0
# 337970  pl.eccc924305ad42ccb53c68aafe33995c                   256002565.0
#
#        Container Library ID Container Name Container Origin Type  \
# 0                       NaN      l.VPTPZRc                   NaN
# 1                       NaN      l.VPTPZRc                   NaN
# 2                       NaN      l.jqyKK1z                   NaN
# 3                       NaN            NaN                   NaN
# 4                       NaN            NaN         USER_PLAYLIST
# ...                     ...            ...                   ...
# 337966                  NaN            NaN                   NaN
# 337967                  NaN            NaN         USER_PLAYLIST
# 337968                  NaN            NaN                  1004
# 337969                  NaN            NaN         USER_PLAYLIST
# 337970                  NaN            NaN                   NaN
#
#         Container Personalized ID  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# ...                           ...
# 337966                        NaN
# 337967                        NaN
# 337968                        NaN
# 337969                        NaN
# 337970                        NaN
#
#                                Container Radio Station ID Container Type  \
# 0                                                     NaN          ALBUM
# 1                                                     NaN          ALBUM
# 2                                                     NaN          ALBUM
# 3                                                     NaN       PLAYLIST
# 4                                                     NaN       PLAYLIST
# ...                                                   ...            ...
# 337966                                                NaN       PLAYLIST
# 337967                                                NaN       PLAYLIST
# 337968  ra.q-GAI6IDNkNzE2ZTg0NmZhOTcyZjAxYWJiNzBmZjc1N...          RADIO
# 337969                                                NaN       PLAYLIST
# 337970                                                NaN       PLAYLIST
#
#        Device App Name  End Position In Milliseconds  \
# 0                  NaN                      250241.0
# 1                  NaN                        6406.0
# 2                  NaN                           0.0
# 3                  NaN                        2586.0
# 4                Music                         202.0
# ...                ...                           ...
# 337966             NaN                         289.0
# 337967           Music                       29329.0
# 337968           Music                        3102.0
# 337969           Music                       29669.0
# 337970             NaN                        1464.0
#
#                                   End Reason Type       Event End Timestamp  \
# 0                            NATURAL_END_OF_TRACK  2017-05-07T13:57:49.384Z
# 1       MANUALLY_SELECTED_PLAYBACK_OF_A_DIFF_ITEM  2017-09-24T08:53:45.578Z
# 2       MANUALLY_SELECTED_PLAYBACK_OF_A_DIFF_ITEM  2019-04-09T05:59:44.553Z
# 3       MANUALLY_SELECTED_PLAYBACK_OF_A_DIFF_ITEM  2020-06-24T22:26:58.405Z
# 4                          TRACK_SKIPPED_FORWARDS  2024-12-04T13:17:01.866Z
# ...                                           ...                       ...
# 337966                     TRACK_SKIPPED_FORWARDS  2017-03-06T14:34:42.848Z
# 337967  MANUALLY_SELECTED_PLAYBACK_OF_A_DIFF_ITEM  2024-08-12T20:30:10.706Z
# 337968                     TRACK_SKIPPED_FORWARDS  2024-10-02T05:05:13.541Z
# 337969                   PLAYBACK_MANUALLY_PAUSED  2024-07-24T12:52:45.871Z
# 337970                    TRACK_SKIPPED_BACKWARDS  2017-03-06T07:22:51.400Z
#
#         Event Post Date Time Event Reason Hint Type  Event Received Timestamp  \
# 0                        NaN          NOT_SPECIFIED  2017-05-07T13:57:49.609Z
# 1                        NaN          NOT_SPECIFIED  2017-09-24T08:53:45.578Z
# 2                        NaN          NOT_SPECIFIED  2019-04-09T05:59:45.696Z
# 3                        NaN          NOT_SPECIFIED  2020-06-24T22:26:58.548Z
# 4                 28888690.0          NOT_SPECIFIED  2024-12-04T13:17:02.013Z
# ...                      ...                    ...                       ...
# 337966                   NaN          NOT_SPECIFIED  2017-03-06T14:34:42.877Z
# 337967                   NaN          NOT_SPECIFIED  2024-08-12T20:30:12.724Z
# 337968            28797430.0          NOT_SPECIFIED  2024-10-02T05:05:13.671Z
# 337969                   NaN          NOT_SPECIFIED  2024-07-24T12:52:45.909Z
# 337970                   NaN          NOT_SPECIFIED  2017-03-06T07:22:51.427Z
#
#            Event Start Timestamp           Event Timestamp Event Type  \
# 0       2017-05-07T13:53:39.143Z                       NaN   PLAY_END
# 1       2017-09-24T08:53:39.172Z                       NaN   PLAY_END
# 2       2019-04-09T05:59:44.553Z                       NaN   PLAY_END
# 3       2020-06-24T22:26:55.819Z                       NaN   PLAY_END
# 4       2024-12-04T13:17:01.664Z  2024-12-04T13:17:01.866Z   PLAY_END
# ...                          ...                       ...        ...
# 337966  2017-03-06T14:34:42.559Z                       NaN   PLAY_END
# 337967  2024-08-12T20:29:41.377Z  2024-08-12T20:30:10.706Z   PLAY_END
# 337968  2024-10-02T05:05:10.439Z  2024-10-02T05:05:13.541Z   PLAY_END
# 337969  2024-07-24T12:52:42.175Z  2024-07-24T12:52:45.871Z   PLAY_END
# 337970  2017-03-06T07:22:49.936Z                       NaN   PLAY_END
#
#                                  Feature Name Is Heavy Rotation Station  \
# 0                      library / album_detail                       NaN
# 1                                     library                       NaN
# 2                      library / album_detail                       NaN
# 3                   library / playlist_detail                       NaN
# 4       library / playlists / playlist_detail                       NaN
# ...                                       ...                       ...
# 337966              library / playlist_detail                       NaN
# 337967  library / playlists / playlist_detail                       NaN
# 337968                       radio / grouping                     False
# 337969  library / playlists / playlist_detail                       NaN
# 337970              library / playlist_detail                       NaN
#
#                    Item Type  Media Duration In Milliseconds Media Type  \
# 0       ITUNES_STORE_CONTENT                        250241.0      AUDIO
# 1       ITUNES_STORE_CONTENT                        206300.0      AUDIO
# 2       ITUNES_STORE_CONTENT                        208111.0      AUDIO
# 3       ITUNES_STORE_CONTENT                        197416.0      AUDIO
# 4       ITUNES_STORE_CONTENT                        307426.0      AUDIO
# ...                      ...                             ...        ...
# 337966  ITUNES_STORE_CONTENT                        268863.0      AUDIO
# 337967  ITUNES_STORE_CONTENT                        141315.0      AUDIO
# 337968  ITUNES_STORE_CONTENT                        184424.0      AUDIO
# 337969  ITUNES_STORE_CONTENT                        147409.0      AUDIO
# 337970  ITUNES_STORE_CONTENT                        223515.0      AUDIO
#
#                      Metrics Client ID  Milliseconds Since Play Offline  \
# 0       3z4HqStGz7TBz4eiz9UHz1Bt1ZMYME                    225.0   False
# 1        3z3hlyxOzF6yz5IPzCExzs8JdfyZs                      0.0   False
# 2       3z17xDCUz2tWz4sazA9Tz1EiZkpm3g                   1143.0   False
# 3       3z2wAvN7zA9Mz4q1zAXjz1KHC3KZYj                    143.0   False
# 4                                  NaN                    147.0   False
# ...                                ...                      ...     ...
# 337966  3z4HqStGz7TBz4eiz9UHz1Bt1ZMYME                     29.0   False
# 337967                             NaN                   2018.0   False
# 337968                             NaN                    130.0   False
# 337969                             NaN                     38.0   False
# 337970  3z4HqStGz7TBz4eiz9UHz1Bt1ZMYME                     27.0   False
#
#         Ownership Type  Personalized Name  Play Duration Milliseconds  \
# 0                  1.0                NaN                    250241.0
# 1                  1.0                NaN                      6406.0
# 2                  1.0                NaN                         0.0
# 3                  1.0        256008457.0                      2586.0
# 4                  1.0        256008977.0                       202.0
# ...                ...                ...                         ...
# 337966             1.0        256002565.0                       289.0
# 337967             1.0        256007429.0                     29329.0
# 337968             1.0                NaN                      3102.0
# 337969             1.0        256009221.0                      3696.0
# 337970             1.0        256002565.0                      1464.0
#
#        Provided Audio Channel Shuffle Play Siri Request  \
# 0                         NaN          NaN          NaN
# 1                         NaN          NaN          NaN
# 2                         NaN          NaN        False
# 3                         NaN          NaN        False
# 4                         NaN   SHUFFLE_ON        False
# ...                       ...          ...          ...
# 337966                    NaN          NaN          NaN
# 337967                    NaN  SHUFFLE_OFF        False
# 337968                    NaN  SHUFFLE_OFF        False
# 337969                    NaN  SHUFFLE_OFF        False
# 337970                    NaN          NaN          NaN
#
#                                                 Song Name Source Radio Type  \
# 0            1-800-273-8255 (feat. Alessia Cara & Khalid)               NaN
# 1                                          Mos Definitely               NaN
# 2                                                   Swang               NaN
# 3                                                Borracho               NaN
# 4                                      Going Back to Cali               NaN
# ...                                                   ...               ...
# 337966                                             Outlet               NaN
# 337967                                    Cant Get Enough               NaN
# 337968  Endless Pain (feat. kXpkX, LXNGVX, b1ueshxrtca...               NaN
# 337969                                   Pretty Girl Vamp               NaN
# 337970                   Drug Dealer (feat. Ariana DeBoo)               NaN
#
#                Source Type  Start Position In Milliseconds Store Front Name  \
# 0       ORIGINATING_DEVICE                               0    United States
# 1       ORIGINATING_DEVICE                               0    United States
# 2       ORIGINATING_DEVICE                               0    United States
# 3       ORIGINATING_DEVICE                               0    United States
# 4       ORIGINATING_DEVICE                               0    United States
# ...                    ...                             ...              ...
# 337966  ORIGINATING_DEVICE                               0    United States
# 337967  ORIGINATING_DEVICE                               0    United States
# 337968  ORIGINATING_DEVICE                               0    United States
# 337969  ORIGINATING_DEVICE                           25973    United States
# 337970  ORIGINATING_DEVICE                               0    United States
#
#         Subscription Bundle ID Subscription Pool Type  Subscription User ID  \
# 0                          NaN                    NaN                   NaN
# 1                          NaN                    NaN                   NaN
# 2                          NaN                    NaN                   NaN
# 3                          NaN                    NaN                   NaN
# 4                 6.450019e+09                    XCX          1.608221e+09
# ...                        ...                    ...                   ...
# 337966                     NaN                    NaN                   NaN
# 337967            6.450019e+09                    XCX          1.608221e+09
# 337968            6.450019e+09                    XCX          1.608221e+09
# 337969            6.450019e+09                    XCX          1.608221e+09
# 337970                     NaN                    NaN                   NaN
#
#        Use Listening History User’s Audio Quality User’s Playback Format  \
# 0                        NaN                  NaN                    NaN
# 1                      False                  NaN                    NaN
# 2                      False                  NaN                    NaN
# 3                      False                  NaN                    NaN
# 4                      False         HIGH_QUALITY                SPATIAL
# ...                      ...                  ...                    ...
# 337966                   NaN                  NaN                    NaN
# 337967                 False                  NaN                    NaN
# 337968                 False                  NaN                    NaN
# 337969                 False                  NaN                    NaN
# 337970                   NaN                  NaN                    NaN
#
#         UTC Offset In Seconds  Vocal Attenuation Duration
# 0                      7200.0                         NaN
# 1                      7200.0                         NaN
# 2                      7200.0                         NaN
# 3                      7200.0                         NaN
# 4                      3600.0                         0.0
# ...                       ...                         ...
# 337966                 3600.0                         NaN
# 337967                 7200.0                         0.0
# 337968                 7200.0                         0.0
# 337969               -21600.0                         0.0
# 337970                 3600.0                         NaN
#
# [337971 rows x 59 columns]

# %%
music_df
# Out:
#        Age Bucket                                         Album Name  \
# 0             NaN                                          Everybody
# 1             NaN                                          Everybody
# 2             NaN                               SremmLife 2 (Deluxe)
# 3             NaN                                  Borracho - Single
# 4           25-34                   Life After Death (2014 Remaster)
# ...           ...                                                ...
# 337966        NaN                                    Outlet - Single
# 337967      25-34                           Cant Get Enough - Single
# 337968        NaN  Endless Pain (feat. kXpkX, LXNGVX, b1ueshxrtca...
# 337969      25-34                          Pretty Girl Vamp - Single
# 337970        NaN          Drug Dealer (feat. Ariana DeBoo) - Single
#
#         Apple ID Number Apple Music Subscription Auto Play  \
# 0            1182611847                     True       NaN
# 1            1182611847                     True       NaN
# 2            1182611847                     True       NaN
# 3            1182611847                     True       NaN
# 4            1182611847                     True  AUTO_OFF
# ...                 ...                      ...       ...
# 337966       1182611847                     True       NaN
# 337967       1182611847                     True  AUTO_OFF
# 337968       1182611847                     True  AUTO_OFF
# 337969       1182611847                     True  AUTO_OFF
# 337970       1182611847                     True       NaN
#
#                                             Build Version Bundle Version  \
# 0       Music/3.1 iOS/10.3.1 model/iPhone8,1 hwp/s8003...            NaN
# 1       iTunes/12.7.0.166 (Macintosh; OS X 10.12.6) Ap...            NaN
# 2       Music/3.1 iOS/12.1.4 model/iPhone9,3 hwp/t8010...            NaN
# 3       Music/3.1 iOS/13.5.1 model/iPhone12,1 hwp/t803...            NaN
# 4       Music/3.1 iOS/18.1.1 model/iPhone14,7 hwp/t811...            3.1
# ...                                                   ...            ...
# 337966  Music/3.0 iOS/10.2.1 model/iPhone8,1 hwp/s8003...            NaN
# 337967  Music/3.1 iOS/17.5.1 model/iPhone14,7 hwp/t811...            3.1
# 337968  Music/3.1 iOS/17.5.1 model/iPhone14,7 hwp/t811...            3.1
# 337969  Music/3.1 iOS/17.5.1 model/iPhone14,7 hwp/t811...            3.1
# 337970  Music/3.0 iOS/10.2.1 model/iPhone8,1 hwp/s8003...            NaN
#
#        Client Build Version  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ...                     ...
# 337966                  NaN
# 337967                  NaN
# 337968                  NaN
# 337969                  NaN
# 337970                  NaN
#
#                                        Client Device Name  \
# 0       itunesstored/1.0 iOS/10.3.1 model/iPhone8,1 hw...
# 1       iTunes/12.7 (Macintosh; OS X 10.12.6) AppleWeb...
# 2       itunescloudd/1.0 iOS/12.1.4 model/iPhone9,3 hw...
# 3       itunescloudd/1.0 iOS/13.5.1 model/iPhone12,1 h...
# 4       itunescloudd/1.0 iOS/18.1.1 model/iPhone14,7 h...
# ...                                                   ...
# 337966  itunesstored/1.0 iOS/10.2.1 model/iPhone8,1 hw...
# 337967  itunescloudd/1.0 iOS/17.5.1 model/iPhone14,7 h...
# 337968  itunescloudd/1.0 iOS/17.5.1 model/iPhone14,7 h...
# 337969  itunescloudd/1.0 iOS/17.5.1 model/iPhone14,7 h...
# 337970  itunesstored/1.0 iOS/10.2.1 model/iPhone8,1 hw...
#
#                              Client IP Address Client Platform  \
# 0                                91.54.241.193            FUSE
# 1                                 91.54.254.90            FUSE
# 2       2a01:598:9280:4f81:28bd:8f9e:86b1:6500            FUSE
# 3                                 217.80.254.6            FUSE
# 4                                          NaN            FUSE
# ...                                        ...             ...
# 337966                           80.187.101.68            FUSE
# 337967                                     NaN            FUSE
# 337968                                     NaN            FUSE
# 337969                                     NaN            FUSE
# 337970                           80.187.101.43            FUSE
#
#         Container Album Name Container Artist Name  \
# 0                  Everybody                   NaN
# 1                  Everybody                   NaN
# 2       SremmLife 2 (Deluxe)                   NaN
# 3                        NaN                   NaN
# 4                        NaN                   NaN
# ...                      ...                   ...
# 337966                   NaN                   NaN
# 337967                   NaN                   NaN
# 337968                   NaN                   NaN
# 337969                   NaN                   NaN
# 337970                   NaN                   NaN
#
#                Container Global Playlist ID  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                       pl.u-b3b8aL3cddoykb
# 4                       pl.u-LdbqWd5FRRJxNl
# ...                                     ...
# 337966  pl.eccc924305ad42ccb53c68aafe33995c
# 337967                  pl.u-6mo4zqytEErBW5
# 337968                                  NaN
# 337969                  pl.u-leylWE8F00qjWe
# 337970  pl.eccc924305ad42ccb53c68aafe33995c
#
#                                Container ID  Container iTunes Playlist ID  \
# 0                                1221017205                           NaN
# 1                                1221017205                           NaN
# 2                                1104588126                           NaN
# 3                       pl.u-b3b8aL3cddoykb                   256008457.0
# 4                       pl.u-LdbqWd5FRRJxNl                   256008977.0
# ...                                     ...                           ...
# 337966  pl.eccc924305ad42ccb53c68aafe33995c                   256002565.0
# 337967                  pl.u-6mo4zqytEErBW5                   256007429.0
# 337968               CgwIByIICIfz9LMEGAIQAQ                           NaN
# 337969                  pl.u-leylWE8F00qjWe                   256009221.0
# 337970  pl.eccc924305ad42ccb53c68aafe33995c                   256002565.0
#
#        Container Library ID Container Name Container Origin Type  \
# 0                       NaN      l.VPTPZRc                   NaN
# 1                       NaN      l.VPTPZRc                   NaN
# 2                       NaN      l.jqyKK1z                   NaN
# 3                       NaN            NaN                   NaN
# 4                       NaN            NaN         USER_PLAYLIST
# ...                     ...            ...                   ...
# 337966                  NaN            NaN                   NaN
# 337967                  NaN            NaN         USER_PLAYLIST
# 337968                  NaN            NaN                  1004
# 337969                  NaN            NaN         USER_PLAYLIST
# 337970                  NaN            NaN                   NaN
#
#         Container Personalized ID  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# ...                           ...
# 337966                        NaN
# 337967                        NaN
# 337968                        NaN
# 337969                        NaN
# 337970                        NaN
#
#                                Container Radio Station ID Container Type  \
# 0                                                     NaN          ALBUM
# 1                                                     NaN          ALBUM
# 2                                                     NaN          ALBUM
# 3                                                     NaN       PLAYLIST
# 4                                                     NaN       PLAYLIST
# ...                                                   ...            ...
# 337966                                                NaN       PLAYLIST
# 337967                                                NaN       PLAYLIST
# 337968  ra.q-GAI6IDNkNzE2ZTg0NmZhOTcyZjAxYWJiNzBmZjc1N...          RADIO
# 337969                                                NaN       PLAYLIST
# 337970                                                NaN       PLAYLIST
#
#        Device App Name  End Position In Milliseconds  \
# 0                  NaN                      250241.0
# 1                  NaN                        6406.0
# 2                  NaN                           0.0
# 3                  NaN                        2586.0
# 4                Music                         202.0
# ...                ...                           ...
# 337966             NaN                         289.0
# 337967           Music                       29329.0
# 337968           Music                        3102.0
# 337969           Music                       29669.0
# 337970             NaN                        1464.0
#
#                                   End Reason Type       Event End Timestamp  \
# 0                            NATURAL_END_OF_TRACK  2017-05-07T13:57:49.384Z
# 1       MANUALLY_SELECTED_PLAYBACK_OF_A_DIFF_ITEM  2017-09-24T08:53:45.578Z
# 2       MANUALLY_SELECTED_PLAYBACK_OF_A_DIFF_ITEM  2019-04-09T05:59:44.553Z
# 3       MANUALLY_SELECTED_PLAYBACK_OF_A_DIFF_ITEM  2020-06-24T22:26:58.405Z
# 4                          TRACK_SKIPPED_FORWARDS  2024-12-04T13:17:01.866Z
# ...                                           ...                       ...
# 337966                     TRACK_SKIPPED_FORWARDS  2017-03-06T14:34:42.848Z
# 337967  MANUALLY_SELECTED_PLAYBACK_OF_A_DIFF_ITEM  2024-08-12T20:30:10.706Z
# 337968                     TRACK_SKIPPED_FORWARDS  2024-10-02T05:05:13.541Z
# 337969                   PLAYBACK_MANUALLY_PAUSED  2024-07-24T12:52:45.871Z
# 337970                    TRACK_SKIPPED_BACKWARDS  2017-03-06T07:22:51.400Z
#
#         Event Post Date Time Event Reason Hint Type  Event Received Timestamp  \
# 0                        NaN          NOT_SPECIFIED  2017-05-07T13:57:49.609Z
# 1                        NaN          NOT_SPECIFIED  2017-09-24T08:53:45.578Z
# 2                        NaN          NOT_SPECIFIED  2019-04-09T05:59:45.696Z
# 3                        NaN          NOT_SPECIFIED  2020-06-24T22:26:58.548Z
# 4                 28888690.0          NOT_SPECIFIED  2024-12-04T13:17:02.013Z
# ...                      ...                    ...                       ...
# 337966                   NaN          NOT_SPECIFIED  2017-03-06T14:34:42.877Z
# 337967                   NaN          NOT_SPECIFIED  2024-08-12T20:30:12.724Z
# 337968            28797430.0          NOT_SPECIFIED  2024-10-02T05:05:13.671Z
# 337969                   NaN          NOT_SPECIFIED  2024-07-24T12:52:45.909Z
# 337970                   NaN          NOT_SPECIFIED  2017-03-06T07:22:51.427Z
#
#            Event Start Timestamp           Event Timestamp Event Type  \
# 0       2017-05-07T13:53:39.143Z                       NaN   PLAY_END
# 1       2017-09-24T08:53:39.172Z                       NaN   PLAY_END
# 2       2019-04-09T05:59:44.553Z                       NaN   PLAY_END
# 3       2020-06-24T22:26:55.819Z                       NaN   PLAY_END
# 4       2024-12-04T13:17:01.664Z  2024-12-04T13:17:01.866Z   PLAY_END
# ...                          ...                       ...        ...
# 337966  2017-03-06T14:34:42.559Z                       NaN   PLAY_END
# 337967  2024-08-12T20:29:41.377Z  2024-08-12T20:30:10.706Z   PLAY_END
# 337968  2024-10-02T05:05:10.439Z  2024-10-02T05:05:13.541Z   PLAY_END
# 337969  2024-07-24T12:52:42.175Z  2024-07-24T12:52:45.871Z   PLAY_END
# 337970  2017-03-06T07:22:49.936Z                       NaN   PLAY_END
#
#                                  Feature Name Is Heavy Rotation Station  \
# 0                      library / album_detail                       NaN
# 1                                     library                       NaN
# 2                      library / album_detail                       NaN
# 3                   library / playlist_detail                       NaN
# 4       library / playlists / playlist_detail                       NaN
# ...                                       ...                       ...
# 337966              library / playlist_detail                       NaN
# 337967  library / playlists / playlist_detail                       NaN
# 337968                       radio / grouping                     False
# 337969  library / playlists / playlist_detail                       NaN
# 337970              library / playlist_detail                       NaN
#
#                    Item Type  Media Duration In Milliseconds Media Type  \
# 0       ITUNES_STORE_CONTENT                        250241.0      AUDIO
# 1       ITUNES_STORE_CONTENT                        206300.0      AUDIO
# 2       ITUNES_STORE_CONTENT                        208111.0      AUDIO
# 3       ITUNES_STORE_CONTENT                        197416.0      AUDIO
# 4       ITUNES_STORE_CONTENT                        307426.0      AUDIO
# ...                      ...                             ...        ...
# 337966  ITUNES_STORE_CONTENT                        268863.0      AUDIO
# 337967  ITUNES_STORE_CONTENT                        141315.0      AUDIO
# 337968  ITUNES_STORE_CONTENT                        184424.0      AUDIO
# 337969  ITUNES_STORE_CONTENT                        147409.0      AUDIO
# 337970  ITUNES_STORE_CONTENT                        223515.0      AUDIO
#
#                      Metrics Client ID  Milliseconds Since Play Offline  \
# 0       3z4HqStGz7TBz4eiz9UHz1Bt1ZMYME                    225.0   False
# 1        3z3hlyxOzF6yz5IPzCExzs8JdfyZs                      0.0   False
# 2       3z17xDCUz2tWz4sazA9Tz1EiZkpm3g                   1143.0   False
# 3       3z2wAvN7zA9Mz4q1zAXjz1KHC3KZYj                    143.0   False
# 4                                  NaN                    147.0   False
# ...                                ...                      ...     ...
# 337966  3z4HqStGz7TBz4eiz9UHz1Bt1ZMYME                     29.0   False
# 337967                             NaN                   2018.0   False
# 337968                             NaN                    130.0   False
# 337969                             NaN                     38.0   False
# 337970  3z4HqStGz7TBz4eiz9UHz1Bt1ZMYME                     27.0   False
#
#         Ownership Type  Personalized Name  Play Duration Milliseconds  \
# 0                  1.0                NaN                    250241.0
# 1                  1.0                NaN                      6406.0
# 2                  1.0                NaN                         0.0
# 3                  1.0        256008457.0                      2586.0
# 4                  1.0        256008977.0                       202.0
# ...                ...                ...                         ...
# 337966             1.0        256002565.0                       289.0
# 337967             1.0        256007429.0                     29329.0
# 337968             1.0                NaN                      3102.0
# 337969             1.0        256009221.0                      3696.0
# 337970             1.0        256002565.0                      1464.0
#
#        Provided Audio Channel Shuffle Play Siri Request  \
# 0                         NaN          NaN          NaN
# 1                         NaN          NaN          NaN
# 2                         NaN          NaN        False
# 3                         NaN          NaN        False
# 4                         NaN   SHUFFLE_ON        False
# ...                       ...          ...          ...
# 337966                    NaN          NaN          NaN
# 337967                    NaN  SHUFFLE_OFF        False
# 337968                    NaN  SHUFFLE_OFF        False
# 337969                    NaN  SHUFFLE_OFF        False
# 337970                    NaN          NaN          NaN
#
#                                                 Song Name Source Radio Type  \
# 0            1-800-273-8255 (feat. Alessia Cara & Khalid)               NaN
# 1                                          Mos Definitely               NaN
# 2                                                   Swang               NaN
# 3                                                Borracho               NaN
# 4                                      Going Back to Cali               NaN
# ...                                                   ...               ...
# 337966                                             Outlet               NaN
# 337967                                    Cant Get Enough               NaN
# 337968  Endless Pain (feat. kXpkX, LXNGVX, b1ueshxrtca...               NaN
# 337969                                   Pretty Girl Vamp               NaN
# 337970                   Drug Dealer (feat. Ariana DeBoo)               NaN
#
#                Source Type  Start Position In Milliseconds Store Front Name  \
# 0       ORIGINATING_DEVICE                               0    United States
# 1       ORIGINATING_DEVICE                               0    United States
# 2       ORIGINATING_DEVICE                               0    United States
# 3       ORIGINATING_DEVICE                               0    United States
# 4       ORIGINATING_DEVICE                               0    United States
# ...                    ...                             ...              ...
# 337966  ORIGINATING_DEVICE                               0    United States
# 337967  ORIGINATING_DEVICE                               0    United States
# 337968  ORIGINATING_DEVICE                               0    United States
# 337969  ORIGINATING_DEVICE                           25973    United States
# 337970  ORIGINATING_DEVICE                               0    United States
#
#         Subscription Bundle ID Subscription Pool Type  Subscription User ID  \
# 0                          NaN                    NaN                   NaN
# 1                          NaN                    NaN                   NaN
# 2                          NaN                    NaN                   NaN
# 3                          NaN                    NaN                   NaN
# 4                 6.450019e+09                    XCX          1.608221e+09
# ...                        ...                    ...                   ...
# 337966                     NaN                    NaN                   NaN
# 337967            6.450019e+09                    XCX          1.608221e+09
# 337968            6.450019e+09                    XCX          1.608221e+09
# 337969            6.450019e+09                    XCX          1.608221e+09
# 337970                     NaN                    NaN                   NaN
#
#        Use Listening History User’s Audio Quality User’s Playback Format  \
# 0                        NaN                  NaN                    NaN
# 1                      False                  NaN                    NaN
# 2                      False                  NaN                    NaN
# 3                      False                  NaN                    NaN
# 4                      False         HIGH_QUALITY                SPATIAL
# ...                      ...                  ...                    ...
# 337966                   NaN                  NaN                    NaN
# 337967                 False                  NaN                    NaN
# 337968                 False                  NaN                    NaN
# 337969                 False                  NaN                    NaN
# 337970                   NaN                  NaN                    NaN
#
#         UTC Offset In Seconds  Vocal Attenuation Duration
# 0                      7200.0                         NaN
# 1                      7200.0                         NaN
# 2                      7200.0                         NaN
# 3                      7200.0                         NaN
# 4                      3600.0                         0.0
# ...                       ...                         ...
# 337966                 3600.0                         NaN
# 337967                 7200.0                         0.0
# 337968                 7200.0                         0.0
# 337969               -21600.0                         0.0
# 337970                 3600.0                         NaN
#
# [337971 rows x 59 columns]

# %%
to_delete = ['Apple Id Number', 'Build Version', 'Client IP Address', 'Device Identifier', 'Metrics Bucket Id', 'Metrics Client Id', 'UTC Offset In Seconds', 'Store Country Name']
music_df.drop(to_delete, axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 2
#       1 to_delete = ['Apple Id Number', 'Build Version', 'Client IP Address', 'Device Identifier', 'Metrics Bucket Id', 'Metrics Client Id', 'UTC Offset In Seconds', 'Store Country Name']
# ----> 2 music_df.drop(to_delete, axis=1, inplace=True)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\generic.py:4549, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547 for axis, labels in axes.items():
#    4548     if labels is not None:
# -> 4549         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4551 if inplace:
#    4552     self._update_inplace(obj)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\generic.py:4591, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4589         new_axis = axis.drop(labels, level=level, errors=errors)
#    4590     else:
# -> 4591         new_axis = axis.drop(labels, errors=errors)
#    4592     indexer = axis.get_indexer(new_axis)
#    4594 # Case for non-unique axis
#    4595 else:
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\indexes\base.py:6699, in Index.drop(self, labels, errors)
#    6697 if mask.any():
#    6698     if errors != "ignore":
# -> 6699         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6700     indexer = indexer[~mask]
#    6701 return self.delete(indexer)
#
# KeyError: "['Apple Id Number', 'Metrics Bucket Id', 'Metrics Client Id', 'Store Country Name'] not found in axis"

# %%
music_df.isnull().sum()

# %%
music_df.shape

# %% [markdown]
# ### Converting timestamp columns to actual TimeStamp

# %% [markdown]
# Timestamp columns - Event End Timestamp, Event Start Timestamp, Event Received Timestamp are not exactly timestamp but string. We have to convert these columns into actual timestamps

# %%
music_df['Event End Timestamp'] = pd.to_datetime(music_df['Event End Timestamp'], format='%Y-%m-%dT%H:%M:%S')
music_df['Event Received Timestamp'] = pd.to_datetime(music_df['Event Received Timestamp'], format='%Y-%m-%dT%H:%M:%S')
music_df['Event Start Timestamp'] = pd.to_datetime(music_df['Event Start Timestamp'], format='%Y-%m-%dT%H:%M:%S')

# %%
music_df.head()

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# Questions to ask for data analysis
#
# 1. Who are the top 10 favourite artists?
# 2. Which are the top 10 songs played?
# 3. Who are top 10 favourite content providers or music labels?
# 4. Which are the top 10 songs that were listened for longest time?
# 5. What is the reason of ending the song most?
# 6. Which are your most loved genre?
# 7. Which media type do you prefer most on Apple Music?
# 8. Do you prefer listening to music when you are online/offline?
# 9. What time do you prefer to listen music?
# 10. Which was the most active month?
# 11. Which was the most active year?
# 12. Total time spent on the platform?

# %% [markdown]
# ### 1. Who are your top 10 favourite artists/singers/band?

# %%
top_10_artist = music_df['Artist Name'].value_counts()[:10]

# %%
fig = px.bar(top_10_artist, title="Top 10 favourite artists", labels={"index":"Artists", 'value':"No. of times song played"}, color_discrete_sequence=px.colors.qualitative.Set2)
fig.show()

# %% [markdown]
# ### 2. Which are the top 20 songs played? (favourite songs)

# %%
top_20_songs = music_df['Content Name'].value_counts()[:20]

# %%
# (optional)
# changing the name of longest song name
as_list = top_20_songs.index.tolist()
idx = as_list.index("I'm the One (feat. Justin Bieber, Quavo, Chance the Rapper & Lil Wayne)")
as_list[idx] = 'I am the one (ft. Justin Bieber)'
top_20_songs.index = as_list

# %%
fig = px.bar(top_20_songs, title="Top 20 favourite songs", labels={"index":"Songs", 'value':"No. of times song played"}, color_discrete_sequence=px.colors.qualitative.Bold)
fig.update_xaxes(tickangle=22)
fig.show()

# %% [markdown]
# ### 3. Which are the top 10 favourite content providers?

# %%
top_10_labels = music_df['Content Provider'].value_counts()[:10]

# %%
# (optional)
# changing the name of longest label name
as_list = top_10_labels.index.tolist()
idx = as_list.index("Super Cassettes Industries Pvt Limited a.k.a. T-Series")
as_list[idx] = 'T-Series'
top_10_labels.index = as_list

# %%
fig = px.bar(top_10_labels, title="Top 20 favourite labels", labels={"index":"Music Labels", 'value':"No. of times song label played"}, color_discrete_sequence=px.colors.qualitative.Pastel)
fig.update_xaxes(tickangle=25)
fig.show()

# %% [markdown]
# What are the top songs played from particular label?

# %%
def top_10_song_of_label(label):
    """
    Function to see what are the top musics played from particular label. 
    """
    # use groupby method and sort ascending
    label_df = music_df[music_df['Content Provider'] == label]
    top_10_song = label_df['Content Name'].value_counts()[:10]
    print(top_10_song)
    fig = px.bar(top_10_song, labels={"index": "Song Names", "value": "No. of time song played", "variable":"Song name"}, title=f"Top songs from {label}")
    fig.show()

# %%
top_10_song_of_label('The Warner Music Group')

# %%
top_10_song_of_label('Super Cassettes Industries Pvt Limited a.k.a. T-Series')

# %% [markdown]
# ### 4. Which are the top 10 songs that were listened for longest time?

# %%
top_longest_played = music_df.groupby('Content Name')['Play Duration Milliseconds'].sum().sort_values(ascending=False)

# %%
# Converting milliseconds to minutes
top_longest_played = top_longest_played / 60000

# %%
colors = px.colors.qualitative

# %%
fig = px.bar(top_longest_played[:10], labels={"Content Name": "Song Names", "value": "Play Time (in mins)", "variable":"Duration"}, color_discrete_sequence=colors.G10_r)
fig.show()

# %% [markdown]
# ### 5.  What is the reason of ending the song most?

# %%
music_df['End Reason Type'].value_counts()

# %%
fig = px.pie(music_df, names='End Reason Type', color_discrete_sequence=colors.Set3)
fig.show()

# %% [markdown]
# I don't usually listen to full songs 😂

# %% [markdown]
# ### 6. Which are your most loved genre?

# %%
top_genre = music_df.Genre.value_counts()[:10]

# %%
fig = px.bar(top_genre, color_discrete_sequence=colors.T10_r)
fig.show()

# %% [markdown]
# ### 7. Which media type do you prefer most on Apple Music?

# %%
fig = px.pie(music_df, names='Media Type', color_discrete_sequence=colors.Dark2, title="Most preferable Media Type (eg. Audio/Video)")
fig.show()

# %% [markdown]
# ### 8. Do you prefer listening to music when you are online/offline?

# %%
music_df.Offline.value_counts()

# %%
fig = px.pie(music_df, names="Offline", title="Do you prefer listening to music Offline?")
fig.show()

# %% [markdown]
# Yeah!! A Lot. Around 38% of the time, I like listening to songs when I am offline. Most probably, I close my eyes and feel the music.

# %% [markdown]
# ### 9. What time do you prefer to listen to music?

# %%
music_df['Event Start Timestamp']

# %%
# converting event start timestamp to separate time section
music_df["Event Start Time"] = music_df['Event Start Timestamp'].dt.time
music_df["Event Start Time"].head()

# %%
hours = music_df["Event Start Time"].groupby(music_df["Event Start Timestamp"].dt.hour).count()

# %%
fig = px.bar(hours, title="Most active hours (24hr)", labels={"value": "count", "Event Start Timestamp":"Timings (hours)"}, color_discrete_sequence=colors.Prism)
fig.update_xaxes(dtick=1)
fig.show()

# %% [markdown]
# Looks like I can hear music at any time from above graph. HAHA!!

# %% [markdown]
# ### 10. What month have you listened to songs most?

# %%
months = music_df["Event Start Time"].groupby(music_df["Event Start Timestamp"].dt.month).count()

# %%
m = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sept', 'Oct', 'Nov','Dec']
fig = px.bar(months, title="Most active Months", text=m, labels={"value": "count", "Event Start Timestamp":"Months"}, color_discrete_sequence=colors.Light24)
fig.update_xaxes(dtick=1)
fig.show()

# %% [markdown]
# ### 11. Which year have you listened to songs most on Apple Music?

# %%
years = music_df["Event Start Time"].groupby(music_df["Event Start Timestamp"].dt.year).count()

# %%
fig = px.bar(years, title="Most active years", labels={"value": "count", "Event Start Timestamp":"Year"}, color_discrete_sequence=colors.Prism_r)
fig.update_xaxes(dtick=1)
fig.show()

# %% [markdown]
# ### 12. Total time spent listening to&nbsp;music

# %%
total_time = music_df['Play Duration Milliseconds'].sum()

# %%
total_mins = total_time/60000
print("Total minutes spent: {:.2f} mins".format(total_mins))
total_hours = total_mins/60
print("Total hours spent: {:.2f} hours".format(total_hours))

# %%
start_time = music_df['Event End Timestamp'].min()
end_time = music_df['Event End Timestamp'].max()

# %%
total_possible_time = (end_time - start_time).days

# %%
total_possible_hours = total_possible_time * 24
print("Total possible time could be spent: {:.2f} hours".format(total_possible_hours))

# %%
hours_spent_list = np.array([total_hours, total_possible_hours])
hours_spent_list_labels = [" Actual Hours Spent", "Possible Hours"]

fig, ax = plt.subplots(figsize=(12,6))
ax.pie(hours_spent_list, labels= hours_spent_list_labels, autopct='%1.1f%%',  explode=[0.2,0.2], startangle=180, shadow = True);
plt.title("Hours Spent Percentage");

# %% [markdown]
# ### Daily average songs played

# %%
total_songs = music_df.shape[0]
print("Daily average of songs played: {:.2f} songs".format(total_songs/total_possible_time))

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=4597a1b6-de90-4f9a-b59d-60c2ea6c17ad' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
